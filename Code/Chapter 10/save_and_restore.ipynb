# %% [markdown]
# Creating the Model, compiling and building it

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
print(len(train_images), len(test_images))
train_images = train_images/255
test_images = test_images/255
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(300, activation='relu'),
  tf.keras.layers.Dense(100, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(loss=tf.keras.losses.sparse_categorical_crossentropy, optimizer='sgd', metrics='accuracy')
history = model.fit(train_images, train_labels, epochs=30, validation_data=(test_images,test_labels))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 60000 10000
# Epoch 1/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7071 - accuracy: 0.7653 - val_loss: 0.5334 - val_accuracy: 0.8145
# Epoch 2/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4799 - accuracy: 0.8323 - val_loss: 0.5042 - val_accuracy: 0.8251
# Epoch 3/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4363 - accuracy: 0.8472 - val_loss: 0.4457 - val_accuracy: 0.8435
# Epoch 4/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4086 - accuracy: 0.8554 - val_loss: 0.4257 - val_accuracy: 0.8502
# Epoch 5/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3878 - accuracy: 0.8633 - val_loss: 0.4173 - val_accuracy: 0.8533
# Epoch 6/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3727 - accuracy: 0.8687 - val_loss: 0.3948 - val_accuracy: 0.8569
# Epoch 7/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3598 - accuracy: 0.8727 - val_loss: 0.3893 - val_accuracy: 0.8611
# Epoch 8/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3478 - accuracy: 0.8760 - val_loss: 0.3948 - val_accuracy: 0.8587
# Epoch 9/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3384 - accuracy: 0.8793 - val_loss: 0.3830 - val_accuracy: 0.8624
# Epoch 10/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3278 - accuracy: 0.8822 - val_loss: 0.3899 - val_accuracy: 0.8574
# Epoch 11/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3205 - accuracy: 0.8849 - val_loss: 0.3676 - val_accuracy: 0.8705
# Epoch 12/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3125 - accuracy: 0.8885 - val_loss: 0.3604 - val_accuracy: 0.8737
# Epoch 13/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3054 - accuracy: 0.8916 - val_loss: 0.3612 - val_accuracy: 0.8707
# Epoch 14/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2992 - accuracy: 0.8929 - val_loss: 0.3535 - val_accuracy: 0.8762
# Epoch 15/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2933 - accuracy: 0.8940 - val_loss: 0.3585 - val_accuracy: 0.8750
# Epoch 16/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2864 - accuracy: 0.8969 - val_loss: 0.3657 - val_accuracy: 0.8682
# Epoch 17/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2807 - accuracy: 0.8987 - val_loss: 0.3396 - val_accuracy: 0.8811
# Epoch 18/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2763 - accuracy: 0.8999 - val_loss: 0.3386 - val_accuracy: 0.8816
# Epoch 19/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2706 - accuracy: 0.9024 - val_loss: 0.3518 - val_accuracy: 0.8772
# Epoch 20/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2662 - accuracy: 0.9039 - val_loss: 0.3521 - val_accuracy: 0.8722
# Epoch 21/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2612 - accuracy: 0.9065 - val_loss: 0.3389 - val_accuracy: 0.8805
# Epoch 22/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2558 - accuracy: 0.9068 - val_loss: 0.3315 - val_accuracy: 0.8823
# Epoch 23/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2519 - accuracy: 0.9082 - val_loss: 0.3279 - val_accuracy: 0.8821
# Epoch 24/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2466 - accuracy: 0.9108 - val_loss: 0.3345 - val_accuracy: 0.8812
# Epoch 25/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2432 - accuracy: 0.9123 - val_loss: 0.3423 - val_accuracy: 0.8780
# Epoch 26/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2403 - accuracy: 0.9120 - val_loss: 0.3378 - val_accuracy: 0.8782
# Epoch 27/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2349 - accuracy: 0.9155 - val_loss: 0.3283 - val_accuracy: 0.8841
# Epoch 28/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2313 - accuracy: 0.9168 - val_loss: 0.3218 - val_accuracy: 0.8827
# Epoch 29/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2274 - accuracy: 0.9179 - val_loss: 0.3245 - val_accuracy: 0.8865
# Epoch 30/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2250 - accuracy: 0.9179 - val_loss: 0.3247 - val_accuracy: 0.8829

# %% [markdown]
# Saving a model

# %%
model.save('fashion_mnist_model.h5')

# %% [markdown]
# Restoring Model

# %%
model = tf.keras.models.load_model('fashion_mnist_model.h5')
