# %% [markdown]
# #Using California Housing Problem

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import  train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
import numpy as np


housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

np.random.seed(42)
tf.random.set_seed(42)
# Out:
# Downloading Cal. housing from https://ndownloader.figshare.com/files/5976036 to /root/scikit_learn_data

# %% [markdown]
# Initizlising the Code with sklearn's california housing problem

# %%
input_ = keras.layers.Input(shape=X_train[:1])
hidden1 = kears.layers.Dense(30, activation='relu')(input_)
hidden2 = keras.layers.Dense(30, activation='relu')(hidden1)
concat = keras.layers.Concatenate()([input_, hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.Model(inputs=[input_], outputs=[output])

# %% [markdown]
# Creating layers for the tensorflow network
# - The First layer is creating the input object, including the shape and dtype
# - Next create Dense layer with 30 neurons using ReLU activation function then passing through the input
# - Create the seccond hidden layer and pass in the previous layer
# - Create Concatenate layer creates a concatenate layer and immediately calls it with the given inputs
# - Create Output layer with single neuron and no activation function and call it like a function passing in the concatenated layer
# - Create a keras model

# %%
X_train_A, X_train_B = X_train[:, :5], X_train[:, 2:]
X_valid_A, X_valid_B = X_valid[:, :5], X_valid[:, 2:]
X_test_A, X_test_B = X_test[:, :5], X_test[:, 2:]
X_new_A, X_new_B = X_test_A[:3], X_test_B[:3]

input_A = keras.layers.Input(shape=[5], name="wide_input")
input_B = keras.layers.Input(shape=[6], name="deep_input")
hidden1 = keras.layers.Dense(30, activation="relu")(input_B)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_A, hidden2])
output = keras.layers.Dense(1, name="main_output")(concat)
aux_output = keras.layers.Dense(1, name="aux_output")(hidden2)
model = keras.models.Model(inputs=[input_A, input_B],
                           outputs=[output, aux_output])

# %% [markdown]
# Creating multiple layers with more than one input

# %%
model.compile(loss="mse", loss_weights=[0.1], optimizer=keras.optimizers.SGD(lr=1e-3))
history = model.fit([X_train_A, X_train_B], [y_train, y_train], epochs=20,
                    validation_data=([X_valid_A, X_valid_B], [y_valid, y_valid]))
# Out:
# Epoch 1/20
# WARNING:tensorflow:Gradients do not exist for variables ['aux_output/kernel:0', 'aux_output/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['aux_output/kernel:0', 'aux_output/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['aux_output/kernel:0', 'aux_output/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['aux_output/kernel:0', 'aux_output/bias:0'] when minimizing the loss.
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4679 - main_output_loss: 4.6787 - aux_output_loss: 0.0000e+00 - val_loss: 0.8019 - val_main_output_loss: 8.0191 - val_aux_output_loss: 0.0000e+00
# Epoch 2/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3328 - main_output_loss: 3.3277 - aux_output_loss: 0.0000e+00 - val_loss: 0.9793 - val_main_output_loss: 9.7926 - val_aux_output_loss: 0.0000e+00
# Epoch 3/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.2538 - main_output_loss: 2.5376 - aux_output_loss: 0.0000e+00 - val_loss: 1.0261 - val_main_output_loss: 10.2609 - val_aux_output_loss: 0.0000e+00
# Epoch 4/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.2043 - main_output_loss: 2.0433 - aux_output_loss: 0.0000e+00 - val_loss: 0.9525 - val_main_output_loss: 9.5247 - val_aux_output_loss: 0.0000e+00
# Epoch 5/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1709 - main_output_loss: 1.7092 - aux_output_loss: 0.0000e+00 - val_loss: 0.8173 - val_main_output_loss: 8.1728 - val_aux_output_loss: 0.0000e+00
# Epoch 6/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1473 - main_output_loss: 1.4728 - aux_output_loss: 0.0000e+00 - val_loss: 0.6859 - val_main_output_loss: 6.8589 - val_aux_output_loss: 0.0000e+00
# Epoch 7/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1302 - main_output_loss: 1.3020 - aux_output_loss: 0.0000e+00 - val_loss: 0.5574 - val_main_output_loss: 5.5738 - val_aux_output_loss: 0.0000e+00
# Epoch 8/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1177 - main_output_loss: 1.1770 - aux_output_loss: 0.0000e+00 - val_loss: 0.4361 - val_main_output_loss: 4.3611 - val_aux_output_loss: 0.0000e+00
# Epoch 9/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1085 - main_output_loss: 1.0845 - aux_output_loss: 0.0000e+00 - val_loss: 0.3542 - val_main_output_loss: 3.5418 - val_aux_output_loss: 0.0000e+00
# Epoch 10/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.1014 - main_output_loss: 1.0141 - aux_output_loss: 0.0000e+00 - val_loss: 0.2896 - val_main_output_loss: 2.8961 - val_aux_output_loss: 0.0000e+00
# Epoch 11/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.0960 - main_output_loss: 0.9600 - aux_output_loss: 0.0000e+00 - val_loss: 0.2363 - val_main_output_loss: 2.3634 - val_aux_output_loss: 0.0000e+00
# Epoch 12/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.0918 - main_output_loss: 0.9177 - aux_output_loss: 0.0000e+00 - val_loss: 0.1974 - val_main_output_loss: 1.9745 - val_aux_output_loss: 0.0000e+00
# Epoch 13/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.0884 - main_output_loss: 0.8836 - aux_output_loss: 0.0000e+00 - val_loss: 0.1660 - val_main_output_loss: 1.6601 - val_aux_output_loss: 0.0000e+00
# Epoch 14/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.0856 - main_output_loss: 0.8557 - aux_output_loss: 0.0000e+00 - val_loss: 0.1417 - val_main_output_loss: 1.4167 - val_aux_output_loss: 0.0000e+00
# Epoch 15/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.0833 - main_output_loss: 0.8326 - aux_output_loss: 0.0000e+00 - val_loss: 0.1231 - val_main_output_loss: 1.2313 - val_aux_output_loss: 0.0000e+00
# Epoch 16/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.0813 - main_output_loss: 0.8132 - aux_output_loss: 0.0000e+00 - val_loss: 0.1092 - val_main_output_loss: 1.0915 - val_aux_output_loss: 0.0000e+00
# Epoch 17/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.0797 - main_output_loss: 0.7966 - aux_output_loss: 0.0000e+00 - val_loss: 0.0984 - val_main_output_loss: 0.9845 - val_aux_output_loss: 0.0000e+00
# Epoch 18/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.0782 - main_output_loss: 0.7823 - aux_output_loss: 0.0000e+00 - val_loss: 0.0906 - val_main_output_loss: 0.9055 - val_aux_output_loss: 0.0000e+00
# Epoch 19/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.0770 - main_output_loss: 0.7697 - aux_output_loss: 0.0000e+00 - val_loss: 0.0844 - val_main_output_loss: 0.8443 - val_aux_output_loss: 0.0000e+00
# Epoch 20/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.0759 - main_output_loss: 0.7586 - aux_output_loss: 0.0000e+00 - val_loss: 0.0801 - val_main_output_loss: 0.8005 - val_aux_output_loss: 0.0000e+00

# %% [markdown]
# Compile and Build
